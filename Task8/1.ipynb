# %% [markdown]
# # Question one
# Solve CartPole-v0 with Q-learning.
# This task has been inspired by: https://github.com/JackFurby/CartPole-v0
#
# ## Q-table
# Here I created a class for encapsulating a q table contianing buckets for discrete values

# %%
import gym
import matplotlib.pyplot as plt
import numpy as np


# TODO create bins for the observations
class Bucketed_Q_Table():
    def __init__(self, observation_space, action_space, num_of_buckets):
        # self._buckets = self._create_buckets(observation_space, num_of_buckets)
        self._buckets = self._create_buckets_v2()
        self._table = np.zeros(([num_of_buckets] * len(observation_space.high) + [action_space.n]))
        print(self._buckets)
        # print(self._table.shape)

    def _create_buckets(self, observation_space, num_of_buckets):
        num_of_observations = len(observation_space.high)
        # print(observation_space.high)
        # print(observation_space.low)
        bucks = []
        for i in range(num_of_observations):
            # Since a bucket contains values between linspace entries the linspace needs one more element than the number of buckets
            bucks.append(np.linspace(observation_space.low[i], observation_space.high[i], num_of_buckets + 1))
        return bucks

    def _create_buckets_v2(self):
        numBins = 20
        obsSpaceSize = len(env.observation_space.high)

        # Get the size of each bucket
        return [
            np.linspace(-4.8, 4.8, numBins),
            np.linspace(-4, 4, numBins),
            np.linspace(-.418, .418, numBins),
            np.linspace(-4, 4, numBins)
        ]

    def _get_bucket_index(self, observation_num, observation):
        for i in range(len(self._buckets[observation_num]) - 1):
            if i == 20:
                print(observation)
                print(observation_num)
            if self._buckets[observation_num][i] <= observation < self._buckets[observation_num][i + 1]:
                return i
        print("OBS")
        return -1

    def optimal_choice(self, observations):
        return np.argmax(self._get_action_q_values(observations))

    def optimal_val(self, observations):
        return np.max(self._get_action_q_values(observations))

    def _get_action_q_values(self, observations):
        arr = self._table
        for i in range(len(observations)):
            arr = arr[self._get_bucket_index(i, observations[i])]
        return arr

    def set_q_value(self, observations, action_index, q_value):
        self._get_action_q_values(observations)[action_index] = q_value
        # self._table[observation_index, self._get_bucket_index(observation_index, observations), action_index] = q_value

    def get_q_value(self, observations, action_index):
        return self._get_action_q_values(observations)[action_index]
        # return self._table[observation_index, self._get_bucket_index(observation_index, observation), action_index]

    def print_table(self):
        print(self._table)

    def get_max(self):
        return np.max(self._table)

# %% [markdown]
# Method for running the finished model

# %%
def run_finished(q_table, k):
    env = gym.make("CartPole-v0")
    for episode_num in range(k):
        done = False
        observation = env.reset()
        while not done:
            env.render()
            action = q_table.optimal_choice(observation)
            observation, reward, done, info = env.step(action)
    env.close()

# %% [markdown]
# Training the model:

# %%
NUM_OF_BUCKETS = 20
NUM_OF_EPISODES = 10000
DISCOUNT_FACTOR = 0.95
LEARNING_RATE = 0.1

eps = lambda episode: (NUM_OF_EPISODES - episode) / NUM_OF_EPISODES

env = gym.make("CartPole-v0")

q_table = Bucketed_Q_Table(env.observation_space, env.action_space, NUM_OF_BUCKETS)

epochs_run_tbl = []
for episode_num in range(NUM_OF_EPISODES):
    done = False
    observation = env.reset()
    epochs_run = 0
    while not done:
        if np.random.uniform(0, 1) < eps(episode_num):
            action = env.action_space.sample()
        else:
            action = q_table.optimal_choice(observation)
        new_observation, reward, done, info = env.step(action)
        if done and epochs_run < 150:
            reward = -200
        current_q = q_table.get_q_value(observation, action)
        max_future_q = q_table.optimal_val(new_observation)
        new_q = (1 - LEARNING_RATE) * current_q + LEARNING_RATE * (reward + DISCOUNT_FACTOR * max_future_q)
        q_table.set_q_value(observation, action, new_q)
        observation = new_observation
        epochs_run += 1
        # print(action)
        # print(current_q)
        # print(max_q)
        # print(new_q)
    if episode_num % 100 == 0:
        print(f"Episode num: {episode_num}, epochs run: {epochs_run},")
        print(eps(episode_num))
        print(q_table.get_max())
    epochs_run_tbl.append(epochs_run)
env.close()
# Out:
# [array([-4.8       , -4.29473684, -3.78947368, -3.28421053, -2.77894737,
#        -2.27368421, -1.76842105, -1.26315789, -0.75789474, -0.25263158,
#         0.25263158,  0.75789474,  1.26315789,  1.76842105,  2.27368421,
#         2.77894737,  3.28421053,  3.78947368,  4.29473684,  4.8       ]), array([-4.        , -3.57894737, -3.15789474, -2.73684211, -2.31578947,
#        -1.89473684, -1.47368421, -1.05263158, -0.63157895, -0.21052632,
#         0.21052632,  0.63157895,  1.05263158,  1.47368421,  1.89473684,
#         2.31578947,  2.73684211,  3.15789474,  3.57894737,  4.        ]), array([-0.418, -0.374, -0.33 , -0.286, -0.242, -0.198, -0.154, -0.11 ,
#        -0.066, -0.022,  0.022,  0.066,  0.11 ,  0.154,  0.198,  0.242,
#         0.286,  0.33 ,  0.374,  0.418]), array([-4.        , -3.57894737, -3.15789474, -2.73684211, -2.31578947,
#        -1.89473684, -1.47368421, -1.05263158, -0.63157895, -0.21052632,
#         0.21052632,  0.63157895,  1.05263158,  1.47368421,  1.89473684,
#         2.31578947,  2.73684211,  3.15789474,  3.57894737,  4.        ])]
# Episode num: 0, epochs run: 13,
# 1.0
# 0.28036225000000004
# Episode num: 100, epochs run: 12,
# 0.99
# 4.266882473045313
# Episode num: 200, epochs run: 30,
# 0.98
# 7.126984837157268
# Episode num: 300, epochs run: 14,
# 0.97
# 9.157413720527469
# Episode num: 400, epochs run: 24,
# 0.96
# 10.639186968484044
# Episode num: 500, epochs run: 16,
# 0.95
# 11.536809642324151
# Episode num: 600, epochs run: 17,
# 0.94
# 12.049080142796633
# Episode num: 700, epochs run: 28,
# 0.93
# 12.851882977166573
# Episode num: 800, epochs run: 36,
# 0.92
# 13.770116981872256
# Episode num: 900, epochs run: 18,
# 0.91
# 14.687862208243537
# Episode num: 1000, epochs run: 22,
# 0.9
# 15.223690008606557
# Episode num: 1100, epochs run: 26,
# 0.89
# 15.561536410132506
# Episode num: 1200, epochs run: 37,
# 0.88
# 16.257085355336404
# Episode num: 1300, epochs run: 18,
# 0.87
# 16.98460588944532
# Episode num: 1400, epochs run: 50,
# 0.86
# 17.340023507633884
# Episode num: 1500, epochs run: 89,
# 0.85
# 17.670817061550423
# Episode num: 1600, epochs run: 41,
# 0.84
# 17.786712375472703
# Episode num: 1700, epochs run: 31,
# 0.83
# 18.28161152869303
# Episode num: 1800, epochs run: 60,
# 0.82
# 18.341727755682527
# Episode num: 1900, epochs run: 54,
# 0.81
# 18.457017601645173
# Episode num: 2000, epochs run: 79,
# 0.8
# 18.477974876284136
# Episode num: 2100, epochs run: 10,
# 0.79
# 18.66212933874805
# Episode num: 2200, epochs run: 12,
# 0.78
# 18.69390811051352
# Episode num: 2300, epochs run: 16,
# 0.77
# 18.911109864338865
# Episode num: 2400, epochs run: 36,
# 0.76
# 18.890383310576958
# Episode num: 2500, epochs run: 14,
# 0.75
# 18.803864905525312
# Episode num: 2600, epochs run: 46,
# 0.74
# 18.88488713318093
# Episode num: 2700, epochs run: 29,
# 0.73
# 18.8685717862074
# Episode num: 2800, epochs run: 59,
# 0.72
# 18.72808250726456
# Episode num: 2900, epochs run: 51,
# 0.71
# 18.99937048461301
# Episode num: 3000, epochs run: 58,
# 0.7
# 18.990433289020196
# Episode num: 3100, epochs run: 33,
# 0.69
# 19.151871758277824
# Episode num: 3200, epochs run: 87,
# 0.68
# 19.234501382277486
# Episode num: 3300, epochs run: 19,
# 0.67
# 19.39302707078511
# Episode num: 3400, epochs run: 50,
# 0.66
# 19.332400632272684
# Episode num: 3500, epochs run: 13,
# 0.65
# 19.361211688526275
# Episode num: 3600, epochs run: 15,
# 0.64
# 19.37547100429571
# Episode num: 3700, epochs run: 44,
# 0.63
# 19.36061807359062
# Episode num: 3800, epochs run: 63,
# 0.62
# 19.460503102020084
# Episode num: 3900, epochs run: 91,
# 0.61
# 19.42378623382986
# Episode num: 4000, epochs run: 90,
# 0.6
# 19.31174244739909
# Episode num: 4100, epochs run: 53,
# 0.59
# 19.360846744708596
# Episode num: 4200, epochs run: 25,
# 0.58
# 19.271482423425482
# Episode num: 4300, epochs run: 92,
# 0.57
# 19.313256941664164
# Episode num: 4400, epochs run: 129,
# 0.56
# 19.398796195699312
# OBS
# Episode num: 4500, epochs run: 137,
# 0.55
# 19.384706457438735
# Episode num: 4600, epochs run: 51,
# 0.54
# 19.09596958663467
# Episode num: 4700, epochs run: 83,
# 0.53
# 19.21016892127986
# Episode num: 4800, epochs run: 52,
# 0.52
# 19.055363369376646
# Episode num: 4900, epochs run: 40,
# 0.51
# 19.210328359414333
# Episode num: 5000, epochs run: 106,
# 0.5
# 19.463247485516234
# Episode num: 5100, epochs run: 10,
# 0.49
# 19.338037874292898
# Episode num: 5200, epochs run: 67,
# 0.48
# 19.348037035692922
# Episode num: 5300, epochs run: 125,
# 0.47
# 19.408858396878273
# Episode num: 5400, epochs run: 83,
# 0.46
# 19.447140279482674
# Episode num: 5500, epochs run: 127,
# 0.45
# 19.379062584575987
# Episode num: 5600, epochs run: 75,
# 0.44
# 19.302253520232284
# Episode num: 5700, epochs run: 200,
# 0.43
# 19.3428428609071
# Episode num: 5800, epochs run: 147,
# 0.42
# 19.32840100699254
# OBS
# OBS
# OBS
# OBS
# OBS
# Episode num: 5900, epochs run: 156,
# 0.41
# 19.268962308354578
# Episode num: 6000, epochs run: 142,
# 0.4
# 19.217849525113586
# Episode num: 6100, epochs run: 200,
# 0.39
# 19.25564963985395
# Episode num: 6200, epochs run: 178,
# 0.38
# 19.456081974774044
# Episode num: 6300, epochs run: 57,
# 0.37
# 19.327403278703255
# OBS
# OBS
# OBS
# OBS
# OBS
# Episode num: 6400, epochs run: 109,
# 0.36
# 19.391000393763143
# OBS
# Episode num: 6500, epochs run: 196,
# 0.35
# 19.44313817555688
# Episode num: 6600, epochs run: 168,
# 0.34
# 19.52001349994066
# OBS
# Episode num: 6700, epochs run: 122,
# 0.33
# 19.416131362729146
# Episode num: 6800, epochs run: 131,
# 0.32
# 19.44346530751065
# Episode num: 6900, epochs run: 154,
# 0.31
# 19.50647097864012
# Episode num: 7000, epochs run: 121,
# 0.3
# 19.420751721811598
# Episode num: 7100, epochs run: 200,
# 0.29
# 19.418098191355085
# Episode num: 7200, epochs run: 185,
# 0.28
# 19.656241727818376
# Episode num: 7300, epochs run: 200,
# 0.27
# 19.60018014023546
# Episode num: 7400, epochs run: 200,
# 0.26
# 19.551612796822006
# Episode num: 7500, epochs run: 190,
# 0.25
# 19.64640091636659
# Episode num: 7600, epochs run: 145,
# 0.24
# 19.68993392004866
# Episode num: 7700, epochs run: 176,
# 0.23
# 19.73907922147781
# OBS
# Episode num: 7800, epochs run: 200,
# 0.22
# 19.65086857662687
# OBS
# OBS
# OBS
# OBS
# OBS
# OBS
# OBS
# OBS
# OBS
# OBS
# OBS
# OBS
# Episode num: 7900, epochs run: 200,
# 0.21
# 19.681347270482146
# Episode num: 8000, epochs run: 200,
# 0.2
# 19.714382014349102
# Episode num: 8100, epochs run: 200,
# 0.19
# 19.748719349631692
# Episode num: 8200, epochs run: 200,
# 0.18
# 19.80866187155143
# Episode num: 8300, epochs run: 157,
# 0.17
# 19.744896978541217
# Episode num: 8400, epochs run: 200,
# 0.16
# 19.792921286871557
# Episode num: 8500, epochs run: 200,
# 0.15
# 19.80221360105983
# Episode num: 8600, epochs run: 151,
# 0.14
# 19.793851729273705
# Episode num: 8700, epochs run: 200,
# 0.13
# 19.81580984705966
# Episode num: 8800, epochs run: 133,
# 0.12
# 19.820344600056195
# Episode num: 8900, epochs run: 126,
# 0.11
# 19.795471940499624
# OBS
# OBS
# OBS
# OBS
# OBS
# Episode num: 9000, epochs run: 165,
# 0.1
# 19.820992609176066
# Episode num: 9100, epochs run: 196,
# 0.09
# 19.837925689393124
# OBS
# OBS
# OBS
# OBS
# OBS
# Episode num: 9200, epochs run: 189,
# 0.08
# 19.830103272139844
# Episode num: 9300, epochs run: 200,
# 0.07
# 19.875466000361733
# Episode num: 9400, epochs run: 182,
# 0.06
# 19.868212350631058
# Episode num: 9500, epochs run: 192,
# 0.05
# 19.81632875761608
# Episode num: 9600, epochs run: 140,
# 0.04
# 19.82054148918544
# Episode num: 9700, epochs run: 200,
# 0.03
# 19.78772821722664
# OBS
# OBS
# OBS
# Episode num: 9800, epochs run: 185,
# 0.02
# 19.79741335384289
# Episode num: 9900, epochs run: 156,
# 0.01
# 19.755857011763403

# %% [markdown]
# Plotting the epochs run result

# %%
plt.plot(epochs_run_tbl, label="Epochs run for each episode")
plt.show()

# %% [markdown]
# Running finished model

# %%
run_finished(q_table, 20)
